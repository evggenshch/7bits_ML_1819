# %% [markdown]
# # Workshop 3. Визуальный анализ данных
#
# 1. Скачайте этот ноутбук к себе.
# 2. Заполните пропущенные ячейки, отвечая на заданные вопросы. Там должен быть код! (если не сказано обратное)
# 3. Сохраните результат в своём гитхаб репозитории.
#
# #### Полезная литература
#
# - [Галерея графиков Matplotlib](https://matplotlib.org/gallery/index.html)
# - [Галерея графиков Seaborn](http://seaborn.pydata.org/examples/index.html)
# - [Открытый курс машинного обучения. Тема 2: Визуализация данных c Python](https://habr.com/company/ods/blog/323210/)

# %% [markdown]
# На этом занятии рассмотрим датасет [Titanic: Machine Learning from Disaster](https://www.kaggle.com/c/titanic).
#
# ### Data Dictionary
#
# |Variable|Definition|Key
# |---|---|---|
# |survival|Survival|0 = No, 1 = Yes|
# |pclass|Ticket class|1 = 1st, 2 = 2nd, 3 = 3rd|
# |sex|Sex| |
# |Age|Age in years| |
# |sibsp|# of siblings / spouses aboard the Titanic| |
# |parch|# of parents / children aboard the Titanic| |
# |ticket|Ticket number| |
# |fare|Passenger fare| |
# |cabin|Cabin number| |
# |embarked|Port of Embarkation|C = Cherbourg, Q = Queenstown, S = Southampton|
#
# #### Variable Notes
#
# **pclass**: A proxy for socio-economic status (SES)
# - 1st = Upper
# - 2nd = Middle
# - 3rd = Lower
#
# **age**: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# **sibsp**: The dataset defines family relations in this way...
# - Sibling = brother, sister, stepbrother, stepsister
# - Spouse = husband, wife (mistresses and fiancés were ignored)
#
# **parch**: The dataset defines family relations in this way...
# - Parent = mother, father
# - Child = daughter, son, stepdaughter, stepson
# - Some children travelled only with a nanny, therefore parch=0 for them.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Считываем обучающую выборку.**

# %%
# !ls
train_df = pd.read_csv("titanic_train.csv", index_col='PassengerId')
# Out:
# adult.csv.gz
# bikes_rent.csv.gz
# data
# Homework_1.ipynb
# titanic_train.csv
# week2_homework_02-01-homework-numpy.ipynb
# week2_homework_02-02-homework-pandas.ipynb
# week2_workshop_02-01-workshop-numpy.ipynb
# week2_workshop_02-02-workshop-pandas.ipynb
# week3_homework_03-01-visualisation-homework.ipynb
# week3_workshop_03-01-visualisation-workshop.ipynb
# Workshop_1.ipynb

# %%
train_df.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
train_df.describe(include='all')
# Out:
#           Survived      Pclass                  Name   Sex         Age  \
# count   891.000000  891.000000                   891   891  714.000000
# unique         NaN         NaN                   891     2         NaN
# top            NaN         NaN  Cleaver, Miss. Alice  male         NaN
# freq           NaN         NaN                     1   577         NaN
# mean      0.383838    2.308642                   NaN   NaN   29.699118
# std       0.486592    0.836071                   NaN   NaN   14.526497
# min       0.000000    1.000000                   NaN   NaN    0.420000
# 25%       0.000000    2.000000                   NaN   NaN   20.125000
# 50%       0.000000    3.000000                   NaN   NaN   28.000000
# 75%       1.000000    3.000000                   NaN   NaN   38.000000
# max       1.000000    3.000000                   NaN   NaN   80.000000
#
#              SibSp       Parch Ticket        Fare        Cabin Embarked
# count   891.000000  891.000000    891  891.000000          204      889
# unique         NaN         NaN    681         NaN          147        3
# top            NaN         NaN   1601         NaN  C23 C25 C27        S
# freq           NaN         NaN      7         NaN            4      644
# mean      0.523008    0.381594    NaN   32.204208          NaN      NaN
# std       1.102743    0.806057    NaN   49.693429          NaN      NaN
# min       0.000000    0.000000    NaN    0.000000          NaN      NaN
# 25%       0.000000    0.000000    NaN    7.910400          NaN      NaN
# 50%       0.000000    0.000000    NaN   14.454200          NaN      NaN
# 75%       1.000000    0.000000    NaN   31.000000          NaN      NaN
# max       8.000000    6.000000    NaN  512.329200          NaN      NaN

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# **Выкинем признак `Cabin`, а потом – все строки, где есть пропуски.**

# %%
train_df = train_df.drop('Cabin', axis=1).dropna()
train_df.info() # обратите внимание, что количество данных стало меньше
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 1 to 891
# Data columns (total 10 columns):
# Survived    712 non-null int64
# Pclass      712 non-null int64
# Name        712 non-null object
# Sex         712 non-null object
# Age         712 non-null float64
# SibSp       712 non-null int64
# Parch       712 non-null int64
# Ticket      712 non-null object
# Fare        712 non-null float64
# Embarked    712 non-null object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 61.2+ KB

# %% [markdown]
# **Постройте попарные зависимости признаков `Age`, `Fare`, `Pclass`, `Sex`, `SibSp`, `Parch`, `Embarked` и `Survived`. (метод `scatter_matrix ` Pandas или `pairplot` Seaborn).**

# %%
#pd.plotting.scatter_matrix(train_df[['Age', 'Fare', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked', 'Survived']], figsize=(50, 50))
sample = train_df
sample['Sex'] = sample['Sex'].replace('male', 1).replace('female', 0)
sample['Embarked'] = sample['Embarked'].replace('S', 2).replace('C', 1).replace('Q', 0)
sns.pairplot(sample[['Age', 'Fare', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked', 'Survived']])

# %% [markdown]
# **Как плата за билет (`Fare`) зависит от класса каюты (`Pclass`)? Постройте boxplot.**

# %%
sns.boxplot(data = train_df, y='Fare', x='Pclass')

# %% [markdown]
# **Такой boxplot получается не очень красивым из-за выбросов.**
#
# **Опционально: создайте признак `Fare_no_out` (стоимости без выбросов), в котором исключаются стоимости, отличающиеся от средней по классу более чем на 2 стандартных отклонения. Важно: надо исключать выбросы именно в зависимости от класса каюты. Иначе исключаться будут только самые большие (1 класс) и малые (3 класс) стоимости.**

# %%
train_df['Fare_no_out'] = train_df['Fare']
fare_pclass1 = train_df[train_df['Pclass'] == 1]['Fare']
fare_pclass2 = train_df[train_df['Pclass'] == 2]['Fare']
fare_pclass3 = train_df[train_df['Pclass'] == 3]['Fare']
mean_pclass1 = train_df[train_df['Pclass'] == 1]['Fare'].mean()
mean_pclass2 = train_df[train_df['Pclass'] == 2]['Fare'].mean()
mean_pclass3 = train_df[train_df['Pclass'] == 3]['Fare'].mean()
std_pclass1 = train_df[train_df['Pclass'] == 1]['Fare'].std()
std_pclass2 = train_df[train_df['Pclass'] == 2]['Fare'].std()
std_pclass3 = train_df[train_df['Pclass'] == 3]['Fare'].std()
fare_pclass1_no_out = train_df[abs(train_df[train_df['Pclass'] == 1]['Fare'] - mean_pclass1) <= 2 * std_pclass1]
fare_pclass2_no_out = train_df[abs(train_df[train_df['Pclass'] == 2]['Fare'] - mean_pclass2) <= 2 * std_pclass2]
fare_pclass3_no_out = train_df[abs(train_df[train_df['Pclass'] == 3]['Fare'] - mean_pclass3) <= 2 * std_pclass3]
train_df['Fare_no_out'] = fare_pclass1_no_out.append(fare_pclass2_no_out).append(fare_pclass3_no_out)
# Out:
# /home/evggenshch/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # This is added back by InteractiveShellApp.init_path()
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-11-ebd8a3cf6f79> in <module>
#       9 std_pclass2 = train_df[train_df['Pclass'] == 2]['Fare'].std()
#      10 std_pclass3 = train_df[train_df['Pclass'] == 3]['Fare'].std()
# ---> 11 fare_pclass1_no_out = train_df[abs(train_df[train_df['Pclass'] == 1]['Fare'] - mean_pclass1) <= 2 * std_pclass1]
#      12 fare_pclass2_no_out = train_df[abs(train_df[train_df['Pclass'] == 2]['Fare'] - mean_pclass2) <= 2 * std_pclass2]
#      13 fare_pclass3_no_out = train_df[abs(train_df[train_df['Pclass'] == 3]['Fare'] - mean_pclass3) <= 2 * std_pclass3]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2720             # check_bool_indexer will throw exception if Series key cannot
#    2721             # be reindexed to match DataFrame rows
# -> 2722             key = check_bool_indexer(self.index, key)
#    2723             indexer = key.nonzero()[0]
#    2724             return self._take(indexer, axis=0)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in check_bool_indexer(ax, key)
#    2354         mask = isna(result._values)
#    2355         if mask.any():
# -> 2356             raise IndexingError('Unalignable boolean Series provided as '
#    2357                                 'indexer (index of the boolean Series and of '
#    2358                                 'the indexed object do not match')
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match

# %% [markdown]
# **Каково соотношение погибших и выживших в зависимости от пола? Отобразите c помощью Seaborn.countplot c аргументом hue.**

# %%
#train_df.groupby('Pclass').count()['Survived']

# %%
sns.countplot(data=train_df, x='Survived', hue='Sex')

# %% [markdown]
# **Каково соотношение погибших и выживших в зависимости от класса каюты? Отобразите c помощью Seaborn.countplot c аргументом hue.**

# %%
sns.countplot(data=train_df, x='Pclass', hue='Survived')

# %% [markdown]
# **Как факт выживания зависит от возраста пассажира? Проверьте (графически) предположение, что молодые чаще выживали. Пусть, условно, молодые - младше 30 лет, пожилые – старше 60 лет.**

# %%
#plt.figure(figsize=(15,8))
np.round(np.log1p(train_df['Age'], 1).unique()
fix, ax = plt.subplots(nrows=2, figsize=(15, 10))
sns.countplot(x='Age', data=train_df[train_df['Survived'] == 1], ax=ax[0])
sns.countplot(x='Age', data=train_df[train_df['Survived'] == 0], ax=ax[1])
# Out:
#   File "<ipython-input-36-8e3434233cb3>", line 3
#     fix, ax = plt.subplots(nrows=2, figsize=(15, 10))
#       ^
# SyntaxError: invalid syntax

# %%
np.round(np.log1p(train_df['Age'], 1).unique()
# Out:
#   File "<ipython-input-39-f9cd8fb6c138>", line 1
#     np.round(np.log1p(train_df['Age'], 1).unique()
#                                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
sns.lmplot(x='Age', y='Survived', data=train_df)

# %%
#sns.jointplot
